# %% [markdown]
# ### Data Import
#
# import data from https://archive.ics.uci.edu/dataset/336/chronic+kidney+disease

# %%
from ucimlrepo import fetch_ucirepo 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# fetch dataset 
chronic_kidney_disease = fetch_ucirepo(id=336) 
  
# data (as pandas dataframes) 
x = chronic_kidney_disease.data.features 
y = chronic_kidney_disease.data.targets

# %%
x.describe(include='all')
# Out:
#                age          bp          sg          al          su     rbc  \
# count   391.000000  388.000000  353.000000  354.000000  351.000000     248
# unique         NaN         NaN         NaN         NaN         NaN       2
# top            NaN         NaN         NaN         NaN         NaN  normal
# freq           NaN         NaN         NaN         NaN         NaN     201
# mean     51.483376   76.469072    1.017408    1.016949    0.450142     NaN
# std      17.169714   13.683637    0.005717    1.352679    1.099191     NaN
# min       2.000000   50.000000    1.005000    0.000000    0.000000     NaN
# 25%      42.000000   70.000000    1.010000    0.000000    0.000000     NaN
# 50%      55.000000   80.000000    1.020000    0.000000    0.000000     NaN
# 75%      64.500000   80.000000    1.020000    2.000000    0.000000     NaN
# max      90.000000  180.000000    1.025000    5.000000    5.000000     NaN
#
# ...

# %% [markdown]
# lets check dtypes to see what kind of data we're working with and to get a clear list of existing colunmns

# %%
x.dtypes
# Out:
# age      float64
# bp       float64
# sg       float64
# al       float64
# su       float64
# rbc          str
# pc           str
# pcc          str
# ba           str
# bgr      float64
# bu       float64
# sc       float64
# sod      float64
# pot      float64
# hemo     float64
# pcv      float64
# wbcc     float64
# rbcc     float64
# htn          str
# dm           str
# cad          str
# appet        str
# pe           str
# ane          str
# dtype: object

# %% [markdown]
# ### Renaming and dropping columns
# Next lets rename columns to the expected names and drop unused ones, on the rename function usused was
# renamed to same name to keep track of which need to be dropped

# %%
x = x.rename(columns={
    'bp': 'blood pressure',
    'sg': 'specific gravity',
    'al': 'albumin',
    'su': 'sugar',
    'rbc': 'rbc',
    'pc': 'pc',
    'pcc': 'pcc',
    'ba': 'ba',
    'bgr': 'blood glucose random',
    'bu': 'blood urea',
    'sc': 'sc',
    'sod': 'sodium',
    'pot': 'potassium',
    'hemo': 'hemoglobin',
    'pcv': 'packed cell volume',
    'wbcc': 'white blood cell count',
    'rbcc': 'red blood cell count',
    'htn': 'htn',
    'dm': 'dm',
    'cad': 'cad',
    'appet': 'appet',
    'pe': 'pe',
    'ane': 'ane'
})
x = x.drop(columns=['rbc', 'pc', 'pcc', 'ba', 'sc', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane'])
x.head()
# Out:
#     age  blood pressure  specific gravity  albumin  sugar  \
# 0  48.0            80.0             1.020      1.0    0.0
# 1   7.0            50.0             1.020      4.0    0.0
# 2  62.0            80.0             1.010      2.0    3.0
# 3  48.0            70.0             1.005      4.0    0.0
# 4  51.0            80.0             1.010      2.0    0.0
#
#    blood glucose random  blood urea  sodium  potassium  hemoglobin  \
# 0                 121.0        36.0     NaN        NaN        15.4
# 1                   NaN        18.0     NaN        NaN        11.3
# 2                 423.0        53.0     NaN        NaN         9.6
# 3                 117.0        56.0   111.0        2.5        11.2
# 4                 106.0        26.0     NaN        NaN        11.6
#
#    packed cell volume  white blood cell count  red blood cell count
# 0                44.0                  7800.0                   5.2
# 1                38.0                  6000.0                   NaN
# ...

# %% [markdown]
# ### Class data renaming
# from dtypes we can see that only 1 column which contains class data, from checking unique we can see theres ckd\t which needs to be cleaned up

# %%
y.dtypes
y['class'].unique()
# Out:
# <StringArray>
# ['ckd', 'ckd\t', 'notckd']
# Length: 3, dtype: str

# %%
y['class'] = y['class'].replace({'ckd\t':'a', 'ckd': 'a', 'notckd':'c'})
y.head()
# Out:
#   class
# 0     a
# 1     a
# 2     a
# 3     a
# 4     a

# %% [markdown]
# ### Merging class data from second frame
# since we have no ids we can just create a new column on x and assign it to y.class

# %%
x['class'] = y['class']

# %% [markdown]
# ### Converting hemo from g/dl to g/l
# google tells us the conversion rate is 1:10, so lets just apply a lambda for that

# %%
x['hemoglobin'] = x['hemoglobin'].apply(lambda x: x * 10)
x
# Out:
#       age  blood pressure  specific gravity  albumin  sugar  \
# 0    48.0            80.0             1.020      1.0    0.0
# 1     7.0            50.0             1.020      4.0    0.0
# 2    62.0            80.0             1.010      2.0    3.0
# 3    48.0            70.0             1.005      4.0    0.0
# 4    51.0            80.0             1.010      2.0    0.0
# ..    ...             ...               ...      ...    ...
# 395  55.0            80.0             1.020      0.0    0.0
# 396  42.0            70.0             1.025      0.0    0.0
# 397  12.0            80.0             1.020      0.0    0.0
# 398  17.0            60.0             1.025      0.0    0.0
# 399  58.0            80.0             1.025      0.0    0.0
#
#      blood glucose random  blood urea  sodium  potassium  hemoglobin  \
# 0                   121.0        36.0     NaN        NaN       154.0
# 1                     NaN        18.0     NaN        NaN       113.0
# ...

# %% [markdown]
# ### Dropping fields with 3 or more NA values
# for this we can just use .dropna with thresh parameter, we have 14 columns so atleast 12 needs to have data for it to be kept, thus we assign thresh=12

# %%
x = x.dropna(thresh=12)
x
# Out:
#       age  blood pressure  specific gravity  albumin  sugar  \
# 0    48.0            80.0             1.020      1.0    0.0
# 3    48.0            70.0             1.005      4.0    0.0
# 4    51.0            80.0             1.010      2.0    0.0
# 5    60.0            90.0             1.015      3.0    0.0
# 6    68.0            70.0             1.010      0.0    0.0
# ..    ...             ...               ...      ...    ...
# 395  55.0            80.0             1.020      0.0    0.0
# 396  42.0            70.0             1.025      0.0    0.0
# 397  12.0            80.0             1.020      0.0    0.0
# 398  17.0            60.0             1.025      0.0    0.0
# 399  58.0            80.0             1.025      0.0    0.0
#
#      blood glucose random  blood urea  sodium  potassium  hemoglobin  \
# 0                   121.0        36.0     NaN        NaN       154.0
# 3                   117.0        56.0   111.0        2.5       112.0
# ...

# %% [markdown]
# ### Splitting dataset to affected and control
# creating 2 new dataframes from x filtered by class

# %%
affected = x[x['class']=='a']
control = x[x['class']=='c']

# %%
affected
# Out:
#       age  blood pressure  specific gravity  albumin  sugar  \
# 0    48.0            80.0             1.020      1.0    0.0
# 3    48.0            70.0             1.005      4.0    0.0
# 4    51.0            80.0             1.010      2.0    0.0
# 5    60.0            90.0             1.015      3.0    0.0
# 6    68.0            70.0             1.010      0.0    0.0
# ..    ...             ...               ...      ...    ...
# 243  62.0            90.0             1.020      2.0    1.0
# 244  64.0            90.0             1.015      3.0    2.0
# 246  48.0           110.0             1.015      3.0    0.0
# 248  59.0            70.0             1.010      1.0    3.0
# 249  56.0            90.0             1.010      4.0    1.0
#
#      blood glucose random  blood urea  sodium  potassium  hemoglobin  \
# 0                   121.0        36.0     NaN        NaN       154.0
# 3                   117.0        56.0   111.0        2.5       112.0
# ...

# %%
control
# Out:
#       age  blood pressure  specific gravity  albumin  sugar  \
# 250  40.0            80.0             1.025      0.0    0.0
# 251  23.0            80.0             1.025      0.0    0.0
# 252  45.0            80.0             1.025      0.0    0.0
# 253  57.0            80.0             1.025      0.0    0.0
# 254  51.0            60.0             1.025      0.0    0.0
# ..    ...             ...               ...      ...    ...
# 395  55.0            80.0             1.020      0.0    0.0
# 396  42.0            70.0             1.025      0.0    0.0
# 397  12.0            80.0             1.020      0.0    0.0
# 398  17.0            60.0             1.025      0.0    0.0
# 399  58.0            80.0             1.025      0.0    0.0
#
#      blood glucose random  blood urea  sodium  potassium  hemoglobin  \
# 250                 140.0        10.0   135.0        5.0       150.0
# 251                  70.0        36.0   150.0        4.6       170.0
# ...

# %%
affected.describe()
# Out:
#               age  blood pressure  specific gravity     albumin       sugar  \
# count  123.000000      125.000000        125.000000  126.000000  126.000000
# mean    57.081301       80.720000          1.013560    1.849206    0.809524
# std     14.465104       15.769305          0.004527    1.437038    1.366539
# min      6.000000       50.000000          1.005000    0.000000    0.000000
# 25%     49.500000       70.000000          1.010000    0.250000    0.000000
# 50%     60.000000       80.000000          1.015000    2.000000    0.000000
# 75%     65.000000       90.000000          1.015000    3.000000    1.000000
# max     90.000000      180.000000          1.025000    5.000000    5.000000
#
#        blood glucose random  blood urea      sodium   potassium  hemoglobin  \
# count            120.000000  125.000000  108.000000  108.000000  125.000000
# mean             181.200000   80.420000  133.731481    4.751852  106.432000
# ...

# %%
control.describe()
# Out:
#               age  blood pressure  specific gravity  albumin  sugar  \
# count  139.000000      137.000000        139.000000    139.0  139.0
# mean    46.568345       71.313869          1.022482      0.0    0.0
# std     15.903719        8.559267          0.002509      0.0    0.0
# min     12.000000       60.000000          1.020000      0.0    0.0
# 25%     34.000000       60.000000          1.020000      0.0    0.0
# 50%     46.000000       70.000000          1.020000      0.0    0.0
# 75%     58.000000       80.000000          1.025000      0.0    0.0
# max     80.000000       80.000000          1.025000      0.0    0.0
#
#        blood glucose random  blood urea      sodium   potassium  hemoglobin  \
# count            135.000000  135.000000  136.000000  136.000000  137.000000
# mean             107.385185   32.874074  141.735294    4.335294  151.883212
# std               18.747730   11.482257    4.792332    0.596351   12.845270
# ...

# %%
def plot_data(df):
    plt.figure(figsize=(20,20))
    for i, col in enumerate(df.select_dtypes(include=['float64'])):
        plt.subplot(4,4,i+1)
        df[col].plot(kind='hist', title=col)
        plt.xlabel(col)
plot_data(affected)

# %%
plot_data(control)

# %% [markdown]
# ### Abnormal values
# control group looks good and doesnt have any abnormalities, affected group has dangerously high bp (180), potassium 40 (which is not possible value), those are easy to filter out

# %%
affected['blood pressure'] = affected['blood pressure'].apply(lambda x: affected['blood pressure'].mean() if x >= 120 else x)
affected['potassium'] = affected['potassium'].apply(lambda x: affected['potassium'].mean() if x >= 20 else x)

# %%
plot_data(affected)

# %% [markdown]
# now its looking better, rbcc and wbcc and blood urea still have an outlier value but as far as i know those are still realistic so those are left in

# %%
aff_corr = affected.drop(columns=['class']).corr()
con_corr = control.drop(columns=['class']).corr()

# %%
aff_corr
# Out:
#                              age  blood pressure  specific gravity   albumin  \
# age                     1.000000        0.081835         -0.004869 -0.016726
# blood pressure          0.081835        1.000000          0.066651  0.107188
# specific gravity       -0.004869        0.066651          1.000000 -0.061509
# albumin                -0.016726        0.107188         -0.061509  1.000000
# sugar                   0.138945        0.077281         -0.044993  0.115618
# blood glucose random    0.205133       -0.029883         -0.083967  0.099096
# blood urea              0.022593        0.136728         -0.037977  0.426974
# sodium                 -0.033951        0.135018          0.143235 -0.179331
# potassium               0.111232        0.120690          0.082478  0.217515
# hemoglobin             -0.006174       -0.135786          0.114042 -0.371257
# packed cell volume     -0.044467       -0.123814          0.106808 -0.329337
# ...

# %%
con_corr
# Out:
#                              age  blood pressure  specific gravity  albumin  \
# age                     1.000000       -0.071093         -0.092814      NaN
# blood pressure         -0.071093        1.000000          0.084470      NaN
# specific gravity       -0.092814        0.084470          1.000000      NaN
# albumin                      NaN             NaN               NaN      NaN
# sugar                        NaN             NaN               NaN      NaN
# blood glucose random    0.101408        0.004094         -0.038416      NaN
# blood urea              0.078620       -0.084057         -0.050116      NaN
# sodium                  0.110581       -0.107489         -0.033880      NaN
# potassium              -0.094361       -0.064606          0.074253      NaN
# hemoglobin              0.056334        0.157748          0.026303      NaN
# packed cell volume     -0.009969       -0.007854         -0.007082      NaN
# ...

# %%
plt.figure(figsize=(10, 10))
plt.imshow(aff_corr, cmap='coolwarm', interpolation='none')
plt.colorbar()
plt.xticks(range(len(aff_corr)), aff_corr.columns, rotation=90)
plt.yticks(range(len(aff_corr)), aff_corr.columns)
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.imshow(con_corr, cmap='coolwarm', interpolation='none')
plt.colorbar()
plt.xticks(range(len(con_corr)), con_corr.columns, rotation=90)
plt.yticks(range(len(con_corr)), con_corr.columns)
plt.show()

# %% [markdown]
# Hemoglobin and packed cell value have very high correlation for affected group but relatively small for control.
#
# In affected group also hemoglobin and red blood cell count has high correlation.
#
# Blood urea has strong negative correlation for packed cell volume and red blood cell count.
#
# For control group albumin and sugar was 0 so no variance there which is also noteworthy.
